# %%
import pandas as pd
import sys
sys.path.append('..')

from src.data_loader import DataLoader
from src.eda import EDA

# Load data using DataLoader
data_loader = DataLoader()
data = data_loader.load_data('C:/Users/dell/Desktop/10Academy/gokada-delivery-optimization/data/driver_locations_during_request.csv')

# Print first few rows of the loaded data to verify
print(data.head())

# Load data
# data = DataLoader.load_data('../data/driver_locations_during_request.csv')
# Out:
#    id  order_id  driver_id driver_action       lat       lng  created_at  \
# 0   1    392001     243828      accepted  6.602207  3.270465         NaN
# 1   2    392001     243588      rejected  6.592097  3.287445         NaN
# 2   3    392001     243830      rejected  6.596133  3.281784         NaN
# 3   4    392001     243539      rejected  6.596142  3.280526         NaN
# 4   5    392001     171653      rejected  6.609232  3.288800         NaN
#
#    updated_at
# 0         NaN
# 1         NaN
# 2         NaN
# 3         NaN
# 4         NaN

# %%
eda = EDA(data)
eda.plot_histograms(['lat', 'lng'])
eda.plot_bar_charts(['driver_action'])
# eda.plot_spatial_distributions()
